# %% [markdown]
# ## Snapshot Usage

# %%
from jupyter_ohm_forks.on_chain import add_on_chain_data
import pandas as pd
import yaml

with open('forks.yaml') as f:
    df = pd.json_normalize(yaml.load(f, Loader=yaml.SafeLoader))

df = add_on_chain_data(df)
df
# Out:
#          name token_ticker                              token_contract  \
# 0     olympus          ohm  0x383518188c0c6d7730d91b2c03a03c837814a899
# 1   otterclam         clam  0xC250e9987A032ACAC293d838726C511E6E1C029d
# 2  hector-dao          hec  0x5C4FDfc5233f935f20D2aDbA572F770c2E377Ab0
#
#   staked_ticker                             staked_contract  \
# 0          sohm  0x04f2694c8fcee23e8fd0dfea1d4f5bb8c352111f
# 1         sclam  0xAAc144Dc08cE39Ed92182dd85ded60E5000C9e67
# 2          shec  0x75bdef24285013387a47775828bec90b91ca9a5f
#
#                              staking_contract  \
# 0  0xFd31c7d00Ca47653c6Ce64Af53c1571f9C36566a
# 1  0xC8B0243F350AA5F8B979b228fAe522DAFC61221a
# 2  0xD12930C8deeDafD788F437879cbA1Ad1E3908Cc5
#
#                               supply_contract token_abi staked_abi  \
# 0  0x0EFFf9199Aa1Ac3C3E34E957567C1BE8bF295034   ohm.abi   sohm.abi
# 1  0x99ee91871cf39A44E3Fc842541274d7eA05AE4b3  clam.abi  sclam.abi
# 2  0x5a0325d0830f10044D82044fd04223F2E0Ea5047   hec.abi   shec.abi
#
#         staking_abi  ... oc_market_price  \
# 0   sohmstaking.abi  ...          441.54
# 1  sclamstaking.abi  ...           20.88
# 2   shecstaking.abi  ...          100.15
#
#                                   oc_epoch oc_staking_rebase oc_five_day_rate  \
# 0    [2200, 767, 13800600, 31053000000000]          0.005757         0.089925
# 1  [28800, 124, 1639440000, 1023856170744]          0.007970         0.126464
# 2    [28800, 165, 24890650, 8309753266751]          0.006911         0.108840
#
#    oc_staking_apy   oc_index oc_next_rebase  oc_staking_tvl  oc_market_cap  \
# 0      535.958119  46.095847       13800600    2.381616e+09   2.691808e+09
# 1     5960.504532   2.671704     1639440000    2.682162e+06   3.475075e+06
# 2     1884.501356   3.164974       24890650    1.204129e+08   1.387952e+08
#
#    oc_staking_ratio
# 0          0.884764
# 1          0.771828
# 2          0.867558
#
# [3 rows x 29 columns]
